# %%
import re

import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
blog_post = '''
            Getting back to work made a difference. After 10 days of nothing but the business of moving and all of its 
            seemingly obligatory messy emotions, it was nice to think of nothing but my patients. I worked Wednesday through 
            Friday, and even with a couple of long days in there, it was a relief to be away from home. It was a relief to be 
            away from unpacking, and contemplating, and deciding. It was a pleasure to think about somebody other than myself 
            for 3 days. I needed that. 
            Those 3 days away, combined with a long run/walk/dip into Lake Superior with Jet yesterday, gave me the energy to 
            unpack nearly my entire basement today. I've still got a lot to do, but things are starting to take shape. My 
            bedroom is almost completely put together. My bathroom and kitchen are done. I've still got boxes in the living 
            room, dining room and the other 2 bedrooms, but I'm getting there.
            Tomorrow I'm heading south to Mayo Clinic for a ketamine infusion. I'm pleased it's not an urgent need at this 
            time, just a regular maintenance dose. Returning to work, getting some exercise, and progressing with my unpacking 
            have each helped stabilize my mood. I'm no longer daily wiping tears from my eyes. In fact, I haven't cried for 
            several days. That, in and of itself, is quite a feat! 
            I'm taking my time with unpacking. I'm doing my best to remain patient. Taking the next right action and 
            maintaining my attitude of gratitude are my focus now. It's still hard, but it's not impossible. Settling into my 
            new home, new routine, and new city will take time. I'm keeping that fact forefront in my mind. I can do this. 
            But I can't do it all today, nor do I have to. Patiently, I'll get it done. 
            '''

# %%
text = re.sub('(\n| {2,})', '', blog_post)
text
# Out:
# "Getting back to work made a difference. After 10 days of nothing but the business of moving and all of its seemingly obligatory messy emotions, it was nice to think of nothing but my patients. I worked Wednesday through Friday, and even with a couple of long days in there, it was a relief to be away from home. It was a relief to be away from unpacking, and contemplating, and deciding. It was a pleasure to think about somebody other than myself for 3 days. I needed that. Those 3 days away, combined with a long run/walk/dip into Lake Superior with Jet yesterday, gave me the energy to unpack nearly my entire basement today. I've still got a lot to do, but things are starting to take shape. My bedroom is almost completely put together. My bathroom and kitchen are done. I've still got boxes in the living room, dining room and the other 2 bedrooms, but I'm getting there.Tomorrow I'm heading south to Mayo Clinic for a ketamine infusion. I'm pleased it's not an urgent need at this time, just a regular maintenance dose. Returning to work, getting some exercise, and progressing with my unpacking have each helped stabilize my mood. I'm no longer daily wiping tears from my eyes. In fact, I haven't cried for several days. That, in and of itself, is quite a feat! I'm taking my time with unpacking. I'm doing my best to remain patient. Taking the next right action and maintaining my attitude of gratitude are my focus now. It's still hard, but it's not impossible. Settling into my new home, new routine, and new city will take time. I'm keeping that fact forefront in my mind. I can do this. But I can't do it all today, nor do I have to. Patiently, I'll get it done. "

# %%
sentences = text.split('.')
print(sentences)
# Out:
# ['Getting back to work made a difference', ' After 10 days of nothing but the business of moving and all of its seemingly obligatory messy emotions, it was nice to think of nothing but my patients', ' I worked Wednesday through Friday, and even with a couple of long days in there, it was a relief to be away from home', ' It was a relief to be away from unpacking, and contemplating, and deciding', ' It was a pleasure to think about somebody other than myself for 3 days', ' I needed that', ' Those 3 days away, combined with a long run/walk/dip into Lake Superior with Jet yesterday, gave me the energy to unpack nearly my entire basement today', " I've still got a lot to do, but things are starting to take shape", ' My bedroom is almost completely put together', ' My bathroom and kitchen are done', " I've still got boxes in the living room, dining room and the other 2 bedrooms, but I'm getting there", "Tomorrow I'm heading south to Mayo Clinic for a ketamine infusion", " I'm pleased it's not an urgent need at this time, just a regular maintenance dose", ' Returning to work, getting some exercise, and progressing with my unpacking have each helped stabilize my mood', " I'm no longer daily wiping tears from my eyes", " In fact, I haven't cried for several days", " That, in and of itself, is quite a feat! I'm taking my time with unpacking", " I'm doing my best to remain patient", ' Taking the next right action and maintaining my attitude of gratitude are my focus now', " It's still hard, but it's not impossible", ' Settling into my new home, new routine, and new city will take time', " I'm keeping that fact forefront in my mind", ' I can do this', " But I can't do it all today, nor do I have to", " Patiently, I'll get it done", ' ']

# %%
authenticator = IAMAuthenticator('16XmaF9pEC7zn21mUHYKgVE8yu8bPtIyg7EOM7WgXfQC')
tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.eu-de.tone-analyzer.watson.cloud.ibm.com/instances/fdb2f990-3610-476d-913e-3fe517d615fe')


tone_analysis = tone_analyzer.tone(
    {'text': text},
    content_type='application/json'
).get_result()

print(json.dumps(tone_analysis, indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.537727,
#         "tone_id": "sadness",
#         "tone_name": "Sadness"
#       },
#       {
#         "score": 0.616419,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       },
#       {
#         "score": 0.618193,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "Getting back to work made a difference.",
#       "tones": []
#     },
#     {
#       "sentence_id": 1,
#       "text": "After 10 days of nothing but the business of moving and all of its seemingly obligatory messy emotions, it was nice to think of nothing but my patients.",
#       "tones": [
#         {
#           "score": 0.768762,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.811849,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 2,
#       "text": "I worked Wednesday through Friday, and even with a couple of long days in there, it was a relief to be away from home.",
#       "tones": []
#     },
#     {
#       "sentence_id": 3,
#       "text": "It was a relief to be away from unpacking, and contemplating, and deciding.",
#       "tones": [
#         {
#           "score": 0.908301,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         },
#         {
#           "score": 0.775702,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 4,
#       "text": "It was a pleasure to think about somebody other than myself for 3 days.",
#       "tones": [
#         {
#           "score": 0.768425,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.73677,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         },
#         {
#           "score": 0.716301,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 5,
#       "text": "I needed that.",
#       "tones": []
#     },
#     {
#       "sentence_id": 6,
#       "text": "Those 3 days away, combined with a long run/walk/dip into Lake Superior with Jet yesterday, gave me the energy to unpack nearly my entire basement today.",
#       "tones": [
#         {
#           "score": 0.518301,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         }
#       ]
#     },
#     {
#       "sentence_id": 7,
#       "text": "I've still got a lot to do, but things are starting to take shape.",
#       "tones": []
#     },
#     {
#       "sentence_id": 8,
#       "text": "My bedroom is almost completely put together.",
#       "tones": []
#     },
#     {
#       "sentence_id": 9,
#       "text": "My bathroom and kitchen are done.",
#       "tones": []
#     },
#     {
#       "sentence_id": 10,
#       "text": "I've still got boxes in the living room, dining room and the other 2 bedrooms, but I'm getting there.Tomorrow I'm heading south to Mayo Clinic for a ketamine infusion.",
#       "tones": []
#     },
#     {
#       "sentence_id": 11,
#       "text": "I'm pleased it's not an urgent need at this time, just a regular maintenance dose.",
#       "tones": [
#         {
#           "score": 0.647986,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 12,
#       "text": "Returning to work, getting some exercise, and progressing with my unpacking have each helped stabilize my mood.",
#       "tones": [
#         {
#           "score": 0.668173,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.58393,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 13,
#       "text": "I'm no longer daily wiping tears from my eyes.",
#       "tones": [
#         {
#           "score": 0.76089,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         }
#       ]
#     },
#     {
#       "sentence_id": 14,
#       "text": "In fact, I haven't cried for several days.",
#       "tones": [
#         {
#           "score": 0.50347,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         },
#         {
#           "score": 0.895415,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 15,
#       "text": "That, in and of itself, is quite a feat!",
#       "tones": [
#         {
#           "score": 0.78696,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.5538,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 16,
#       "text": "I'm taking my time with unpacking.",
#       "tones": []
#     },
#     {
#       "sentence_id": 17,
#       "text": "I'm doing my best to remain patient.",
#       "tones": [
#         {
#           "score": 0.596327,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 18,
#       "text": "Taking the next right action and maintaining my attitude of gratitude are my focus now.",
#       "tones": [
#         {
#           "score": 0.891059,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.532616,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 19,
#       "text": "It's still hard, but it's not impossible.",
#       "tones": [
#         {
#           "score": 0.820595,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         },
#         {
#           "score": 0.801827,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 20,
#       "text": "Settling into my new home, new routine, and new city will take time.",
#       "tones": [
#         {
#           "score": 0.566064,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 21,
#       "text": "I'm keeping that fact forefront in my mind.",
#       "tones": [
#         {
#           "score": 0.965509,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         },
#         {
#           "score": 0.898327,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 22,
#       "text": "I can do this.",
#       "tones": []
#     },
#     {
#       "sentence_id": 23,
#       "text": "But I can't do it all today, nor do I have to.",
#       "tones": [
#         {
#           "score": 0.948292,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 24,
#       "text": "Patiently, I'll get it done.",
#       "tones": [
#         {
#           "score": 0.965509,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     }
#   ]
# }
